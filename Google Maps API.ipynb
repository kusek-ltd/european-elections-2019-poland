# %% [markdown]
# https://maps.googleapis.com/maps/api/geocode/json?address=Ambasada%20RP%20Rruga%20e%20Durresit%20123%20Tiran%C3%AB%201001&key=AIzaSyCBr_7KX7kueGMZWE-no27h0GDHzJZrUZo
#
# https://developers.google.com/maps/documentation/geocoding/intro

# %% [markdown]
# #

# %%
import requests 
import json

def get_coordinates(address):
    
    URL = "https://maps.googleapis.com/maps/api/geocode/json"

    PARAMS = {'address':address, 'key' : 'AIzaSyCBr_7KX7kueGMZWE-no27h0GDHzJZrUZo'} 

    r = requests.get(url = URL, params = PARAMS) 

    data = r.json() 

    latitude = data['results'][0]['geometry']['location']['lat'] 
    longitude = data['results'][0]['geometry']['location']['lng'] 
    formatted_address = data['results'][0]['formatted_address'] 
  
    return {'latitude' : latitude, 'longitude' : longitude, 'formatted_address' : formatted_address}

# %%
import json
import os
gmina_id = '20101'

def add_coordinates():
    projectDirectory = "/Users/nataliakusek/PycharmProjects/european-elections-2019-poland"
    with open(os.path.join(projectDirectory, 'wyniki', '{}.json'.format(gmina_id)), 'r', encoding='utf8') as gmina_protocol_file:
        gmina_protocol = json.load(gmina_protocol_file)
        for _, protocol in gmina_protocol.items():
            address = protocol['info']["Siedziba"]
            coordinates = get_coordinates(address)
            protocol['info']['Siedziba'] = {'address' : address}
            protocol['info']['Siedziba'].update(coordinates)
            return gmina_protocol
        
add_coordinates()
# Out:
# 457895
# {'457895': {'id': '457895',
#   'info': {'Siedziba': {'address': 'Szkoła Podstawowa Nr 3, ul. Ceramiczna 5, 59-700 Bolesławiec',
#     'latitude': 51.2670965,
#     'longitude': 15.5450731,
#     'formatted_address': 'Ceramiczna 5, 59-700 Bolesławiec, Poland'},
#    'Numer': '1',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '1213'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '1543'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '1543'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '577'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '636'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '636'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '1'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
#     'count': '0'},
#    {'id': '8d.',
#     'name': 'Liczba kopert zwrotnych, w których znajdowała się niezaklejona koperta na kartę do głosowania',
#     'count': '0'},
#    {'id': '8e.',
#     'name': 'Liczba kopert na kartę do głosowania wrzuconych do urny',
#     'count': '0'},
#    {'id': '9.', 'name': 'Liczba kart wyjętych z urny', 'count': '636'},
#    {'id': '9a.',
#     'name': 'w tym liczba kart wyjętych z kopert na karty do głosowania',
#     'count': '0'},
#    {'id': '10.',
#     'name': 'Liczba kart nieważnych (innych niż urzędowo ustalone lub nieopatrzonych pieczęcią obwodowej komisji wyborczej)',
#     'count': '0'},
#    {'id': '11.', 'name': 'Liczba kart ważnych', 'count': '636'},
#    {'id': '12.',
#     'name': 'Liczba głosów nieważnych (z kart ważnych)',
#     'count': '1'},
#    {'id': '12a.',
#     'name': 'w tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list',
#     'count': '1'},
#    {'id': '12b.',
#     'name': 'w tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata',
#     'count': '0'},
#    {'id': '12c.',
#     'name': 'w tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście, której rejestracja została unieważniona',
#     'count': '0'},
#    {'id': '13.',
#     'name': 'Liczba głosów ważnych oddanych łącznie na wszystkie listy kandydatów (z kart ważnych)',
#     'count': '635'}],
#   'lists': [{'name': 'Nr listy 1 - KOMITET WYBORCZY WYBORCÓW KONFEDERACJA KORWIN BRAUN LIROY NARODOWCY',
#     'candidates': [{'name': 'IWASZKIEWICZ Robert Jarosław', 'votes': '12'},
#      {'name': 'ŻUREK Piotr Grzegorz', 'votes': '0'},
#      {'name': 'POPLICHA Dagmara Ewa', 'votes': '0'},
#      {'name': 'SZKARUPSKI Daniel', 'votes': '0'},
#      {'name': 'CZERNIAK Hubert Stanisław', 'votes': '14'},
#      {'name': 'GIELERT Katarzyna Zofia', 'votes': '0'},
#      {'name': 'JARMUŁOWICZ Lidia Maria', 'votes': '0'},
#      {'name': 'BIELECKA Halszka Beata', 'votes': '0'},
#      {'name': 'DASZYŃSKA-HERCUŃ Anna Maria', 'votes': '0'},
#      {'name': 'KORWIN-MIKKE Janusz Ryszard', 'votes': '9'}],
#     'total votes': '35'},
#    {'name': 'Nr listy 2 - KOMITET WYBORCZY WIOSNA ROBERTA BIEDRONIA',
#     'candidates': [{'name': 'ŚMISZEK Krzysztof Jan', 'votes': '21'},
#      {'name': 'LUBINIECKA-RÓŻYŁO Katarzyna Elżbieta', 'votes': '5'},
#      {'name': 'CHOJNOWSKI Szymon Piotr', 'votes': '3'},
#      {'name': 'MIGOCZ Izabela Monika', 'votes': '1'},
#      {'name': 'SYSKA Michał Jan', 'votes': '1'},
#      {'name': 'LEMPART Marta Mirosława', 'votes': '6'},
#      {'name': 'PILC Jarosław Stanisław', 'votes': '1'},
#      {'name': 'ODROWSKA Katarzyna', 'votes': '1'},
#      {'name': 'ZATKA Natalia Iwona', 'votes': '1'},
#      {'name': 'KOTARBA Mariusz', 'votes': '0'}],
#     'total votes': '40'},
#    {'name': 'Nr listy 3 - KOALICYJNY KOMITET WYBORCZY KOALICJA EUROPEJSKA PO PSL SLD .N ZIELONI',
#     'candidates': [{'name': 'OCHOJSKA-OKOŃSKA Janina Maria', 'votes': '167'},
#      {'name': 'DUDA Jarosław', 'votes': '23'},
#      {'name': 'SEKUŁA-SZMAJDZIŃSKA Małgorzata Helena', 'votes': '52'},
#      {'name': 'BUŁA Andrzej', 'votes': '2'},
#      {'name': 'ROKICKA Julia Agata', 'votes': '5'},
#      {'name': 'MRZYGŁOCKA Izabela Katarzyna', 'votes': '2'},
#      {'name': 'KOZAKIEWICZ Władysław', 'votes': '4'},
#      {'name': 'STĘPIEŃ Elżbieta Krystyna', 'votes': '2'},
#      {'name': 'PROROK Genowefa Katarzyna', 'votes': '0'},
#      {'name': 'MIESZKOWSKI Krzysztof', 'votes': '7'}],
#     'total votes': '264'},
#    {'name': 'Nr listy 4 - KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ',
#     'candidates': [{'name': 'ZALEWSKA Anna Elżbieta', 'votes': '111'},
#      {'name': 'KEMPA Beata Agnieszka', 'votes': '110'},
#      {'name': 'KŁOSOWSKI Sławomir', 'votes': '12'},
#      {'name': 'KISIELEWICZ Andrzej Marian', 'votes': '3'},
#      {'name': 'SZWED Aleksander Jakub', 'votes': '4'},
#      {'name': 'ŚLUSARZ Rafał Józef', 'votes': '9'},
#      {'name': 'CZOCHARA Katarzyna Beata', 'votes': '2'},
#      {'name': 'BACZYŃSKI Jacek Marcin', 'votes': '5'},
#      {'name': 'ŻOŁNIERUK Beata Izabela', 'votes': '0'},
#      {'name': 'STACHOWIAK-RÓŻECKA Mirosława Agnieszka', 'votes': '7'}],
#     'total votes': '263'},
#    {'name': 'Nr listy 5 - KOALICYJNY KOMITET WYBORCZY LEWICA RAZEM - PARTIA RAZEM, UNIA PRACY, RSS',
#     'candidates': [{'name': 'ZAWISZA Marcelina Monika', 'votes': '4'},
#      {'name': 'PRZYSTAJKO Jerzy', 'votes': '0'},
#      {'name': 'PIWCEWICZ Jolanta Anna', 'votes': '0'},
#      {'name': 'BROWARNY Wojciech Jan', 'votes': '0'},
#      {'name': 'JAROŃSKA Kamila Maria', 'votes': '0'},
#      {'name': 'MAKÓWKA Jacek Edward', 'votes': '0'},
#      {'name': 'STABROWSKA Anna Ewa', 'votes': '0'},
#      {'name': 'DROST Andrzej Oswald', 'votes': '0'},
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '0'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '4'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '8'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '6'},
#      {'name': 'MAZUR Aneta', 'votes': '4'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '2'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '2'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '3'},
#      {'name': 'ZYCH Anna', 'votes': '4'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '0'}],
#     'total votes': '29'}]},
#  '457896': {'id': '457896',
#   'info': {'Siedziba': 'Szkoła Podstawowa Nr 3, ul. Ceramiczna 5, 59-700 Bolesławiec',
#    'Numer': '2',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '1000'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '1358'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '1358'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '341'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '659'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '659'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '1'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
#     'count': '0'},
#    {'id': '8d.',
#     'name': 'Liczba kopert zwrotnych, w których znajdowała się niezaklejona koperta na kartę do głosowania',
#     'count': '0'},
#    {'id': '8e.',
#     'name': 'Liczba kopert na kartę do głosowania wrzuconych do urny',
#     'count': '0'},
#    {'id': '9.', 'name': 'Liczba kart wyjętych z urny', 'count': '659'},
#    {'id': '9a.',
#     'name': 'w tym liczba kart wyjętych z kopert na karty do głosowania',
#     'count': '0'},
#    {'id': '10.',
#     'name': 'Liczba kart nieważnych (innych niż urzędowo ustalone lub nieopatrzonych pieczęcią obwodowej komisji wyborczej)',
#     'count': '0'},
#    {'id': '11.', 'name': 'Liczba kart ważnych', 'count': '659'},
#    {'id': '12.',
#     'name': 'Liczba głosów nieważnych (z kart ważnych)',
#     'count': '2'},
#    {'id': '12a.',
#     'name': 'w tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list',
#     'count': '2'},
#    {'id': '12b.',
#     'name': 'w tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata',
#     'count': '0'},
#    {'id': '12c.',
#     'name': 'w tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście, której rejestracja została unieważniona',
#     'count': '0'},
#    {'id': '13.',
#     'name': 'Liczba głosów ważnych oddanych łącznie na wszystkie listy kandydatów (z kart ważnych)',
#     'count': '657'}],
#   'lists': [{'name': 'Nr listy 1 - KOMITET WYBORCZY WYBORCÓW KONFEDERACJA KORWIN BRAUN LIROY NARODOWCY',
#     'candidates': [{'name': 'IWASZKIEWICZ Robert Jarosław', 'votes': '9'},
#      {'name': 'ŻUREK Piotr Grzegorz', 'votes': '1'},
#      {'name': 'POPLICHA Dagmara Ewa', 'votes': '0'},
#      {'name': 'SZKARUPSKI Daniel', 'votes': '1'},
#      {'name': 'CZERNIAK Hubert Stanisław', 'votes': '3'},
#      {'name': 'GIELERT Katarzyna Zofia', 'votes': '0'},
#      {'name': 'JARMUŁOWICZ Lidia Maria', 'votes': '0'},
#      {'name': 'BIELECKA Halszka Beata', 'votes': '3'},
#      {'name': 'DASZYŃSKA-HERCUŃ Anna Maria', 'votes': '0'},
#      {'name': 'KORWIN-MIKKE Janusz Ryszard', 'votes': '13'}],
#     'total votes': '30'},
#    {'name': 'Nr listy 2 - KOMITET WYBORCZY WIOSNA ROBERTA BIEDRONIA',
#     'candidates': [{'name': 'ŚMISZEK Krzysztof Jan', 'votes': '29'},
#      {'name': 'LUBINIECKA-RÓŻYŁO Katarzyna Elżbieta', 'votes': '7'},
#      {'name': 'CHOJNOWSKI Szymon Piotr', 'votes': '4'},
#      {'name': 'MIGOCZ Izabela Monika', 'votes': '1'},
#      {'name': 'SYSKA Michał Jan', 'votes': '4'},
#      {'name': 'LEMPART Marta Mirosława', 'votes': '6'},
#      {'name': 'PILC Jarosław Stanisław', 'votes': '1'},
#      {'name': 'ODROWSKA Katarzyna', 'votes': '2'},
#      {'name': 'ZATKA Natalia Iwona', 'votes': '2'},
#      {'name': 'KOTARBA Mariusz', 'votes': '0'}],
#     'total votes': '56'},
#    {'name': 'Nr listy 3 - KOALICYJNY KOMITET WYBORCZY KOALICJA EUROPEJSKA PO PSL SLD .N ZIELONI',
#     'candidates': [{'name': 'OCHOJSKA-OKOŃSKA Janina Maria', 'votes': '201'},
#      {'name': 'DUDA Jarosław', 'votes': '10'},
#      {'name': 'SEKUŁA-SZMAJDZIŃSKA Małgorzata Helena', 'votes': '69'},
#      {'name': 'BUŁA Andrzej', 'votes': '2'},
#      {'name': 'ROKICKA Julia Agata', 'votes': '6'},
#      {'name': 'MRZYGŁOCKA Izabela Katarzyna', 'votes': '1'},
#      {'name': 'KOZAKIEWICZ Władysław', 'votes': '4'},
#      {'name': 'STĘPIEŃ Elżbieta Krystyna', 'votes': '3'},
#      {'name': 'PROROK Genowefa Katarzyna', 'votes': '1'},
#      {'name': 'MIESZKOWSKI Krzysztof', 'votes': '9'}],
#     'total votes': '306'},
#    {'name': 'Nr listy 4 - KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ',
#     'candidates': [{'name': 'ZALEWSKA Anna Elżbieta', 'votes': '90'},
#      {'name': 'KEMPA Beata Agnieszka', 'votes': '91'},
#      {'name': 'KŁOSOWSKI Sławomir', 'votes': '4'},
#      {'name': 'KISIELEWICZ Andrzej Marian', 'votes': '10'},
#      {'name': 'SZWED Aleksander Jakub', 'votes': '5'},
#      {'name': 'ŚLUSARZ Rafał Józef', 'votes': '10'},
#      {'name': 'CZOCHARA Katarzyna Beata', 'votes': '4'},
#      {'name': 'BACZYŃSKI Jacek Marcin', 'votes': '3'},
#      {'name': 'ŻOŁNIERUK Beata Izabela', 'votes': '2'},
#      {'name': 'STACHOWIAK-RÓŻECKA Mirosława Agnieszka', 'votes': '20'}],
#     'total votes': '239'},
#    {'name': 'Nr listy 5 - KOALICYJNY KOMITET WYBORCZY LEWICA RAZEM - PARTIA RAZEM, UNIA PRACY, RSS',
#     'candidates': [{'name': 'ZAWISZA Marcelina Monika', 'votes': '4'},
#      {'name': 'PRZYSTAJKO Jerzy', 'votes': '0'},
#      {'name': 'PIWCEWICZ Jolanta Anna', 'votes': '0'},
#      {'name': 'BROWARNY Wojciech Jan', 'votes': '0'},
#      {'name': 'JAROŃSKA Kamila Maria', 'votes': '1'},
#      {'name': 'MAKÓWKA Jacek Edward', 'votes': '0'},
#      {'name': 'STABROWSKA Anna Ewa', 'votes': '0'},
#      {'name': 'DROST Andrzej Oswald', 'votes': '0'},
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '0'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '5'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '18'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '0'},
#      {'name': 'MAZUR Aneta', 'votes': '0'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '0'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '0'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '1'},
#      {'name': 'ZYCH Anna', 'votes': '1'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '1'}],
#     'total votes': '21'}]},
#  '457897': {'id': '457897',
#   'info': {'Siedziba': 'Szkoła Podstawowa Nr 5, ul. Dolne Młyny 60, 59-700 Bolesławiec',
#    'Numer': '3',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '1100'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '1440'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '1440'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '429'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '671'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '671'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '2'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
#     'count': '0'},
#    {'id': '8d.',
#     'name': 'Liczba kopert zwrotnych, w których znajdowała się niezaklejona koperta na kartę do głosowania',
#     'count': '0'},
#    {'id': '8e.',
#     'name': 'Liczba kopert na kartę do głosowania wrzuconych do urny',
#     'count': '0'},
#    {'id': '9.', 'name': 'Liczba kart wyjętych z urny', 'count': '671'},
#    {'id': '9a.',
#     'name': 'w tym liczba kart wyjętych z kopert na karty do głosowania',
#     'count': '0'},
#    {'id': '10.',
#     'name': 'Liczba kart nieważnych (innych niż urzędowo ustalone lub nieopatrzonych pieczęcią obwodowej komisji wyborczej)',
#     'count': '0'},
#    {'id': '11.', 'name': 'Liczba kart ważnych', 'count': '671'},
#    {'id': '12.',
#     'name': 'Liczba głosów nieważnych (z kart ważnych)',
#     'count': '8'},
#    {'id': '12a.',
#     'name': 'w tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list',
#     'count': '7'},
#    {'id': '12b.',
#     'name': 'w tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata',
#     'count': '1'},
#    {'id': '12c.',
#     'name': 'w tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście, której rejestracja została unieważniona',
#     'count': '0'},
#    {'id': '13.',
#     'name': 'Liczba głosów ważnych oddanych łącznie na wszystkie listy kandydatów (z kart ważnych)',
#     'count': '663'}],
#   'lists': [{'name': 'Nr listy 1 - KOMITET WYBORCZY WYBORCÓW KONFEDERACJA KORWIN BRAUN LIROY NARODOWCY',
#     'candidates': [{'name': 'IWASZKIEWICZ Robert Jarosław', 'votes': '11'},
#      {'name': 'ŻUREK Piotr Grzegorz', 'votes': '1'},
#      {'name': 'POPLICHA Dagmara Ewa', 'votes': '0'},
#      {'name': 'SZKARUPSKI Daniel', 'votes': '0'},
#      {'name': 'CZERNIAK Hubert Stanisław', 'votes': '20'},
#      {'name': 'GIELERT Katarzyna Zofia', 'votes': '2'},
#      {'name': 'JARMUŁOWICZ Lidia Maria', 'votes': '0'},
#      {'name': 'BIELECKA Halszka Beata', 'votes': '0'},
#      {'name': 'DASZYŃSKA-HERCUŃ Anna Maria', 'votes': '0'},
#      {'name': 'KORWIN-MIKKE Janusz Ryszard', 'votes': '13'}],
#     'total votes': '47'},
#    {'name': 'Nr listy 2 - KOMITET WYBORCZY WIOSNA ROBERTA BIEDRONIA',
#     'candidates': [{'name': 'ŚMISZEK Krzysztof Jan', 'votes': '16'},
#      {'name': 'LUBINIECKA-RÓŻYŁO Katarzyna Elżbieta', 'votes': '6'},
#      {'name': 'CHOJNOWSKI Szymon Piotr', 'votes': '0'},
#      {'name': 'MIGOCZ Izabela Monika', 'votes': '2'},
#      {'name': 'SYSKA Michał Jan', 'votes': '2'},
#      {'name': 'LEMPART Marta Mirosława', 'votes': '3'},
#      {'name': 'PILC Jarosław Stanisław', 'votes': '0'},
#      {'name': 'ODROWSKA Katarzyna', 'votes': '1'},
#      {'name': 'ZATKA Natalia Iwona', 'votes': '1'},
#      {'name': 'KOTARBA Mariusz', 'votes': '0'}],
#     'total votes': '31'},
#    {'name': 'Nr listy 3 - KOALICYJNY KOMITET WYBORCZY KOALICJA EUROPEJSKA PO PSL SLD .N ZIELONI',
#     'candidates': [{'name': 'OCHOJSKA-OKOŃSKA Janina Maria', 'votes': '179'},
#      {'name': 'DUDA Jarosław', 'votes': '9'},
#      {'name': 'SEKUŁA-SZMAJDZIŃSKA Małgorzata Helena', 'votes': '84'},
#      {'name': 'BUŁA Andrzej', 'votes': '3'},
#      {'name': 'ROKICKA Julia Agata', 'votes': '4'},
#      {'name': 'MRZYGŁOCKA Izabela Katarzyna', 'votes': '0'},
#      {'name': 'KOZAKIEWICZ Władysław', 'votes': '3'},
#      {'name': 'STĘPIEŃ Elżbieta Krystyna', 'votes': '5'},
#      {'name': 'PROROK Genowefa Katarzyna', 'votes': '0'},
#      {'name': 'MIESZKOWSKI Krzysztof', 'votes': '3'}],
#     'total votes': '290'},
#    {'name': 'Nr listy 4 - KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ',
#     'candidates': [{'name': 'ZALEWSKA Anna Elżbieta', 'votes': '106'},
#      {'name': 'KEMPA Beata Agnieszka', 'votes': '86'},
#      {'name': 'KŁOSOWSKI Sławomir', 'votes': '15'},
#      {'name': 'KISIELEWICZ Andrzej Marian', 'votes': '12'},
#      {'name': 'SZWED Aleksander Jakub', 'votes': '3'},
#      {'name': 'ŚLUSARZ Rafał Józef', 'votes': '6'},
#      {'name': 'CZOCHARA Katarzyna Beata', 'votes': '6'},
#      {'name': 'BACZYŃSKI Jacek Marcin', 'votes': '5'},
#      {'name': 'ŻOŁNIERUK Beata Izabela', 'votes': '0'},
#      {'name': 'STACHOWIAK-RÓŻECKA Mirosława Agnieszka', 'votes': '17'}],
#     'total votes': '256'},
#    {'name': 'Nr listy 5 - KOALICYJNY KOMITET WYBORCZY LEWICA RAZEM - PARTIA RAZEM, UNIA PRACY, RSS',
#     'candidates': [{'name': 'ZAWISZA Marcelina Monika', 'votes': '5'},
#      {'name': 'PRZYSTAJKO Jerzy', 'votes': '1'},
#      {'name': 'PIWCEWICZ Jolanta Anna', 'votes': '1'},
#      {'name': 'BROWARNY Wojciech Jan', 'votes': '2'},
#      {'name': 'JAROŃSKA Kamila Maria', 'votes': '0'},
#      {'name': 'MAKÓWKA Jacek Edward', 'votes': '0'},
#      {'name': 'STABROWSKA Anna Ewa', 'votes': '1'},
#      {'name': 'DROST Andrzej Oswald', 'votes': '0'},
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '1'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '11'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '15'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '5'},
#      {'name': 'MAZUR Aneta', 'votes': '3'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '3'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '1'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '0'},
#      {'name': 'ZYCH Anna', 'votes': '1'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '0'}],
#     'total votes': '28'}]},
#  '457898': {'id': '457898',
#   'info': {'Siedziba': 'Szkoła Podstawowa Nr 5, ul. Dolne Młyny 60, 59-700 Bolesławiec',
#    'Numer': '4',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '1106'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '1467'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '1467'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '390'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '716'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '716'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '2'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
#     'count': '0'},
#    {'id': '8d.',
#     'name': 'Liczba kopert zwrotnych, w których znajdowała się niezaklejona koperta na kartę do głosowania',
#     'count': '0'},
#    {'id': '8e.',
#     'name': 'Liczba kopert na kartę do głosowania wrzuconych do urny',
#     'count': '0'},
#    {'id': '9.', 'name': 'Liczba kart wyjętych z urny', 'count': '716'},
#    {'id': '9a.',
#     'name': 'w tym liczba kart wyjętych z kopert na karty do głosowania',
#     'count': '0'},
#    {'id': '10.',
#     'name': 'Liczba kart nieważnych (innych niż urzędowo ustalone lub nieopatrzonych pieczęcią obwodowej komisji wyborczej)',
#     'count': '0'},
#    {'id': '11.', 'name': 'Liczba kart ważnych', 'count': '716'},
#    {'id': '12.',
#     'name': 'Liczba głosów nieważnych (z kart ważnych)',
#     'count': '3'},
#    {'id': '12a.',
#     'name': 'w tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list',
#     'count': '2'},
#    {'id': '12b.',
#     'name': 'w tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata',
#     'count': '1'},
#    {'id': '12c.',
#     'name': 'w tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście, której rejestracja została unieważniona',
#     'count': '0'},
#    {'id': '13.',
#     'name': 'Liczba głosów ważnych oddanych łącznie na wszystkie listy kandydatów (z kart ważnych)',
#     'count': '713'}],
#   'lists': [{'name': 'Nr listy 1 - KOMITET WYBORCZY WYBORCÓW KONFEDERACJA KORWIN BRAUN LIROY NARODOWCY',
#     'candidates': [{'name': 'IWASZKIEWICZ Robert Jarosław', 'votes': '13'},
#      {'name': 'ŻUREK Piotr Grzegorz', 'votes': '1'},
#      {'name': 'POPLICHA Dagmara Ewa', 'votes': '0'},
#      {'name': 'SZKARUPSKI Daniel', 'votes': '0'},
#      {'name': 'CZERNIAK Hubert Stanisław', 'votes': '19'},
#      {'name': 'GIELERT Katarzyna Zofia', 'votes': '0'},
#      {'name': 'JARMUŁOWICZ Lidia Maria', 'votes': '0'},
#      {'name': 'BIELECKA Halszka Beata', 'votes': '0'},
#      {'name': 'DASZYŃSKA-HERCUŃ Anna Maria', 'votes': '1'},
#      {'name': 'KORWIN-MIKKE Janusz Ryszard', 'votes': '17'}],
#     'total votes': '51'},
#    {'name': 'Nr listy 2 - KOMITET WYBORCZY WIOSNA ROBERTA BIEDRONIA',
#     'candidates': [{'name': 'ŚMISZEK Krzysztof Jan', 'votes': '18'},
#      {'name': 'LUBINIECKA-RÓŻYŁO Katarzyna Elżbieta', 'votes': '3'},
#      {'name': 'CHOJNOWSKI Szymon Piotr', 'votes': '1'},
#      {'name': 'MIGOCZ Izabela Monika', 'votes': '1'},
#      {'name': 'SYSKA Michał Jan', 'votes': '0'},
#      {'name': 'LEMPART Marta Mirosława', 'votes': '4'},
#      {'name': 'PILC Jarosław Stanisław', 'votes': '1'},
#      {'name': 'ODROWSKA Katarzyna', 'votes': '0'},
#      {'name': 'ZATKA Natalia Iwona', 'votes': '1'},
#      {'name': 'KOTARBA Mariusz', 'votes': '1'}],
#     'total votes': '30'},
#    {'name': 'Nr listy 3 - KOALICYJNY KOMITET WYBORCZY KOALICJA EUROPEJSKA PO PSL SLD .N ZIELONI',
#     'candidates': [{'name': 'OCHOJSKA-OKOŃSKA Janina Maria', 'votes': '204'},
#      {'name': 'DUDA Jarosław', 'votes': '22'},
#      {'name': 'SEKUŁA-SZMAJDZIŃSKA Małgorzata Helena', 'votes': '97'},
#      {'name': 'BUŁA Andrzej', 'votes': '5'},
#      {'name': 'ROKICKA Julia Agata', 'votes': '2'},
#      {'name': 'MRZYGŁOCKA Izabela Katarzyna', 'votes': '3'},
#      {'name': 'KOZAKIEWICZ Władysław', 'votes': '2'},
#      {'name': 'STĘPIEŃ Elżbieta Krystyna', 'votes': '0'},
#      {'name': 'PROROK Genowefa Katarzyna', 'votes': '2'},
#      {'name': 'MIESZKOWSKI Krzysztof', 'votes': '4'}],
#     'total votes': '341'},
#    {'name': 'Nr listy 4 - KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ',
#     'candidates': [{'name': 'ZALEWSKA Anna Elżbieta', 'votes': '101'},
#      {'name': 'KEMPA Beata Agnieszka', 'votes': '107'},
#      {'name': 'KŁOSOWSKI Sławomir', 'votes': '7'},
#      {'name': 'KISIELEWICZ Andrzej Marian', 'votes': '6'},
#      {'name': 'SZWED Aleksander Jakub', 'votes': '5'},
#      {'name': 'ŚLUSARZ Rafał Józef', 'votes': '10'},
#      {'name': 'CZOCHARA Katarzyna Beata', 'votes': '6'},
#      {'name': 'BACZYŃSKI Jacek Marcin', 'votes': '6'},
#      {'name': 'ŻOŁNIERUK Beata Izabela', 'votes': '3'},
#      {'name': 'STACHOWIAK-RÓŻECKA Mirosława Agnieszka', 'votes': '17'}],
#     'total votes': '268'},
#    {'name': 'Nr listy 5 - KOALICYJNY KOMITET WYBORCZY LEWICA RAZEM - PARTIA RAZEM, UNIA PRACY, RSS',
#     'candidates': [{'name': 'ZAWISZA Marcelina Monika', 'votes': '7'},
#      {'name': 'PRZYSTAJKO Jerzy', 'votes': '0'},
#      {'name': 'PIWCEWICZ Jolanta Anna', 'votes': '0'},
#      {'name': 'BROWARNY Wojciech Jan', 'votes': '0'},
#      {'name': 'JAROŃSKA Kamila Maria', 'votes': '0'},
#      {'name': 'MAKÓWKA Jacek Edward', 'votes': '0'},
#      {'name': 'STABROWSKA Anna Ewa', 'votes': '1'},
#      {'name': 'DROST Andrzej Oswald', 'votes': '0'},
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '0'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '8'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '10'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '2'},
#      {'name': 'MAZUR Aneta', 'votes': '0'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '0'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '0'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '1'},
#      {'name': 'ZYCH Anna', 'votes': '2'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '0'}],
#     'total votes': '15'}]},
#  '457899': {'id': '457899',
#   'info': {'Siedziba': 'Szkoła Podstawowa Nr 5, ul. Dolne Młyny 60, 59-700 Bolesławiec',
#    'Numer': '5',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '1100'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '1399'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '1399'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '469'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '631'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '631'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '2'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
#     'count': '0'},
#    {'id': '8d.',
#     'name': 'Liczba kopert zwrotnych, w których znajdowała się niezaklejona koperta na kartę do głosowania',
#     'count': '0'},
#    {'id': '8e.',
#     'name': 'Liczba kopert na kartę do głosowania wrzuconych do urny',
#     'count': '0'},
#    {'id': '9.', 'name': 'Liczba kart wyjętych z urny', 'count': '631'},
#    {'id': '9a.',
#     'name': 'w tym liczba kart wyjętych z kopert na karty do głosowania',
#     'count': '0'},
#    {'id': '10.',
#     'name': 'Liczba kart nieważnych (innych niż urzędowo ustalone lub nieopatrzonych pieczęcią obwodowej komisji wyborczej)',
#     'count': '0'},
#    {'id': '11.', 'name': 'Liczba kart ważnych', 'count': '631'},
#    {'id': '12.',
#     'name': 'Liczba głosów nieważnych (z kart ważnych)',
#     'count': '9'},
#    {'id': '12a.',
#     'name': 'w tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list',
#     'count': '6'},
#    {'id': '12b.',
#     'name': 'w tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata',
#     'count': '3'},
#    {'id': '12c.',
#     'name': 'w tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście, której rejestracja została unieważniona',
#     'count': '0'},
#    {'id': '13.',
#     'name': 'Liczba głosów ważnych oddanych łącznie na wszystkie listy kandydatów (z kart ważnych)',
#     'count': '622'}],
#   'lists': [{'name': 'Nr listy 1 - KOMITET WYBORCZY WYBORCÓW KONFEDERACJA KORWIN BRAUN LIROY NARODOWCY',
#     'candidates': [{'name': 'IWASZKIEWICZ Robert Jarosław', 'votes': '5'},
#      {'name': 'ŻUREK Piotr Grzegorz', 'votes': '0'},
#      {'name': 'POPLICHA Dagmara Ewa', 'votes': '1'},
#      {'name': 'SZKARUPSKI Daniel', 'votes': '0'},
#      {'name': 'CZERNIAK Hubert Stanisław', 'votes': '17'},
#      {'name': 'GIELERT Katarzyna Zofia', 'votes': '0'},
#      {'name': 'JARMUŁOWICZ Lidia Maria', 'votes': '0'},
#      {'name': 'BIELECKA Halszka Beata', 'votes': '0'},
#      {'name': 'DASZYŃSKA-HERCUŃ Anna Maria', 'votes': '0'},
#      {'name': 'KORWIN-MIKKE Janusz Ryszard', 'votes': '9'}],
#     'total votes': '32'},
#    {'name': 'Nr listy 2 - KOMITET WYBORCZY WIOSNA ROBERTA BIEDRONIA',
#     'candidates': [{'name': 'ŚMISZEK Krzysztof Jan', 'votes': '19'},
#      {'name': 'LUBINIECKA-RÓŻYŁO Katarzyna Elżbieta', 'votes': '11'},
#      {'name': 'CHOJNOWSKI Szymon Piotr', 'votes': '3'},
#      {'name': 'MIGOCZ Izabela Monika', 'votes': '1'},
#      {'name': 'SYSKA Michał Jan', 'votes': '2'},
#      {'name': 'LEMPART Marta Mirosława', 'votes': '2'},
#      {'name': 'PILC Jarosław Stanisław', 'votes': '0'},
#      {'name': 'ODROWSKA Katarzyna', 'votes': '1'},
#      {'name': 'ZATKA Natalia Iwona', 'votes': '0'},
#      {'name': 'KOTARBA Mariusz', 'votes': '0'}],
#     'total votes': '39'},
#    {'name': 'Nr listy 3 - KOALICYJNY KOMITET WYBORCZY KOALICJA EUROPEJSKA PO PSL SLD .N ZIELONI',
#     'candidates': [{'name': 'OCHOJSKA-OKOŃSKA Janina Maria', 'votes': '187'},
#      {'name': 'DUDA Jarosław', 'votes': '9'},
#      {'name': 'SEKUŁA-SZMAJDZIŃSKA Małgorzata Helena', 'votes': '77'},
#      {'name': 'BUŁA Andrzej', 'votes': '4'},
#      {'name': 'ROKICKA Julia Agata', 'votes': '3'},
#      {'name': 'MRZYGŁOCKA Izabela Katarzyna', 'votes': '3'},
#      {'name': 'KOZAKIEWICZ Władysław', 'votes': '7'},
#      {'name': 'STĘPIEŃ Elżbieta Krystyna', 'votes': '3'},
#      {'name': 'PROROK Genowefa Katarzyna', 'votes': '1'},
#      {'name': 'MIESZKOWSKI Krzysztof', 'votes': '6'}],
#     'total votes': '300'},
#    {'name': 'Nr listy 4 - KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ',
#     'candidates': [{'name': 'ZALEWSKA Anna Elżbieta', 'votes': '87'},
#      {'name': 'KEMPA Beata Agnieszka', 'votes': '88'},
#      {'name': 'KŁOSOWSKI Sławomir', 'votes': '9'},
#      {'name': 'KISIELEWICZ Andrzej Marian', 'votes': '8'},
#      {'name': 'SZWED Aleksander Jakub', 'votes': '5'},
#      {'name': 'ŚLUSARZ Rafał Józef', 'votes': '7'},
#      {'name': 'CZOCHARA Katarzyna Beata', 'votes': '0'},
#      {'name': 'BACZYŃSKI Jacek Marcin', 'votes': '3'},
#      {'name': 'ŻOŁNIERUK Beata Izabela', 'votes': '4'},
#      {'name': 'STACHOWIAK-RÓŻECKA Mirosława Agnieszka', 'votes': '14'}],
#     'total votes': '225'},
#    {'name': 'Nr listy 5 - KOALICYJNY KOMITET WYBORCZY LEWICA RAZEM - PARTIA RAZEM, UNIA PRACY, RSS',
#     'candidates': [{'name': 'ZAWISZA Marcelina Monika', 'votes': '5'},
#      {'name': 'PRZYSTAJKO Jerzy', 'votes': '0'},
#      {'name': 'PIWCEWICZ Jolanta Anna', 'votes': '3'},
#      {'name': 'BROWARNY Wojciech Jan', 'votes': '1'},
#      {'name': 'JAROŃSKA Kamila Maria', 'votes': '1'},
#      {'name': 'MAKÓWKA Jacek Edward', 'votes': '0'},
#      {'name': 'STABROWSKA Anna Ewa', 'votes': '0'},
#      {'name': 'DROST Andrzej Oswald', 'votes': '0'},
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '1'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '11'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '7'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '1'},
#      {'name': 'MAZUR Aneta', 'votes': '2'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '1'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '1'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '2'},
#      {'name': 'ZYCH Anna', 'votes': '1'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '0'}],
#     'total votes': '15'}]},
#  '457900': {'id': '457900',
#   'info': {'Siedziba': 'Szkoła Podstawowa Nr 2, ul. Juliusza Słowackiego 2, 59-700 Bolesławiec',
#    'Numer': '6',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '1001'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '1334'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '1334'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '532'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '469'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '469'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '2'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
#     'count': '0'},
#    {'id': '8d.',
#     'name': 'Liczba kopert zwrotnych, w których znajdowała się niezaklejona koperta na kartę do głosowania',
#     'count': '0'},
#    {'id': '8e.',
#     'name': 'Liczba kopert na kartę do głosowania wrzuconych do urny',
#     'count': '0'},
#    {'id': '9.', 'name': 'Liczba kart wyjętych z urny', 'count': '469'},
#    {'id': '9a.',
#     'name': 'w tym liczba kart wyjętych z kopert na karty do głosowania',
#     'count': '0'},
#    {'id': '10.',
#     'name': 'Liczba kart nieważnych (innych niż urzędowo ustalone lub nieopatrzonych pieczęcią obwodowej komisji wyborczej)',
#     'count': '0'},
#    {'id': '11.', 'name': 'Liczba kart ważnych', 'count': '469'},
#    {'id': '12.',
#     'name': 'Liczba głosów nieważnych (z kart ważnych)',
#     'count': '4'},
#    {'id': '12a.',
#     'name': 'w tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list',
#     'count': '4'},
#    {'id': '12b.',
#     'name': 'w tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata',
#     'count': '0'},
#    {'id': '12c.',
#     'name': 'w tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście, której rejestracja została unieważniona',
#     'count': '0'},
#    {'id': '13.',
#     'name': 'Liczba głosów ważnych oddanych łącznie na wszystkie listy kandydatów (z kart ważnych)',
#     'count': '465'}],
#   'lists': [{'name': 'Nr listy 1 - KOMITET WYBORCZY WYBORCÓW KONFEDERACJA KORWIN BRAUN LIROY NARODOWCY',
#     'candidates': [{'name': 'IWASZKIEWICZ Robert Jarosław', 'votes': '3'},
#      {'name': 'ŻUREK Piotr Grzegorz', 'votes': '4'},
#      {'name': 'POPLICHA Dagmara Ewa', 'votes': '0'},
#      {'name': 'SZKARUPSKI Daniel', 'votes': '2'},
#      {'name': 'CZERNIAK Hubert Stanisław', 'votes': '5'},
#      {'name': 'GIELERT Katarzyna Zofia', 'votes': '1'},
#      {'name': 'JARMUŁOWICZ Lidia Maria', 'votes': '1'},
#      {'name': 'BIELECKA Halszka Beata', 'votes': '3'},
#      {'name': 'DASZYŃSKA-HERCUŃ Anna Maria', 'votes': '0'},
#      {'name': 'KORWIN-MIKKE Janusz Ryszard', 'votes': '6'}],
#     'total votes': '25'},
#    {'name': 'Nr listy 2 - KOMITET WYBORCZY WIOSNA ROBERTA BIEDRONIA',
#     'candidates': [{'name': 'ŚMISZEK Krzysztof Jan', 'votes': '17'},
#      {'name': 'LUBINIECKA-RÓŻYŁO Katarzyna Elżbieta', 'votes': '6'},
#      {'name': 'CHOJNOWSKI Szymon Piotr', 'votes': '0'},
#      {'name': 'MIGOCZ Izabela Monika', 'votes': '1'},
#      {'name': 'SYSKA Michał Jan', 'votes': '1'},
#      {'name': 'LEMPART Marta Mirosława', 'votes': '1'},
#      {'name': 'PILC Jarosław Stanisław', 'votes': '0'},
#      {'name': 'ODROWSKA Katarzyna', 'votes': '4'},
#      {'name': 'ZATKA Natalia Iwona', 'votes': '1'},
#      {'name': 'KOTARBA Mariusz', 'votes': '0'}],
#     'total votes': '31'},
#    {'name': 'Nr listy 3 - KOALICYJNY KOMITET WYBORCZY KOALICJA EUROPEJSKA PO PSL SLD .N ZIELONI',
#     'candidates': [{'name': 'OCHOJSKA-OKOŃSKA Janina Maria', 'votes': '104'},
#      {'name': 'DUDA Jarosław', 'votes': '14'},
#      {'name': 'SEKUŁA-SZMAJDZIŃSKA Małgorzata Helena', 'votes': '65'},
#      {'name': 'BUŁA Andrzej', 'votes': '1'},
#      {'name': 'ROKICKA Julia Agata', 'votes': '2'},
#      {'name': 'MRZYGŁOCKA Izabela Katarzyna', 'votes': '0'},
#      {'name': 'KOZAKIEWICZ Władysław', 'votes': '6'},
#      {'name': 'STĘPIEŃ Elżbieta Krystyna', 'votes': '5'},
#      {'name': 'PROROK Genowefa Katarzyna', 'votes': '1'},
#      {'name': 'MIESZKOWSKI Krzysztof', 'votes': '2'}],
#     'total votes': '200'},
#    {'name': 'Nr listy 4 - KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ',
#     'candidates': [{'name': 'ZALEWSKA Anna Elżbieta', 'votes': '77'},
#      {'name': 'KEMPA Beata Agnieszka', 'votes': '55'},
#      {'name': 'KŁOSOWSKI Sławomir', 'votes': '10'},
#      {'name': 'KISIELEWICZ Andrzej Marian', 'votes': '10'},
#      {'name': 'SZWED Aleksander Jakub', 'votes': '3'},
#      {'name': 'ŚLUSARZ Rafał Józef', 'votes': '6'},
#      {'name': 'CZOCHARA Katarzyna Beata', 'votes': '7'},
#      {'name': 'BACZYŃSKI Jacek Marcin', 'votes': '0'},
#      {'name': 'ŻOŁNIERUK Beata Izabela', 'votes': '2'},
#      {'name': 'STACHOWIAK-RÓŻECKA Mirosława Agnieszka', 'votes': '14'}],
#     'total votes': '184'},
#    {'name': 'Nr listy 5 - KOALICYJNY KOMITET WYBORCZY LEWICA RAZEM - PARTIA RAZEM, UNIA PRACY, RSS',
#     'candidates': [{'name': 'ZAWISZA Marcelina Monika', 'votes': '1'},
#      {'name': 'PRZYSTAJKO Jerzy', 'votes': '1'},
#      {'name': 'PIWCEWICZ Jolanta Anna', 'votes': '1'},
#      {'name': 'BROWARNY Wojciech Jan', 'votes': '1'},
#      {'name': 'JAROŃSKA Kamila Maria', 'votes': '1'},
#      {'name': 'MAKÓWKA Jacek Edward', 'votes': '0'},
#      {'name': 'STABROWSKA Anna Ewa', 'votes': '1'},
#      {'name': 'DROST Andrzej Oswald', 'votes': '0'},
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '0'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '6'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '10'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '2'},
#      {'name': 'MAZUR Aneta', 'votes': '4'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '0'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '0'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '0'},
#      {'name': 'ZYCH Anna', 'votes': '2'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '1'}],
#     'total votes': '19'}]},
#  '457901': {'id': '457901',
#   'info': {'Siedziba': 'Szkoła Podstawowa Nr 1, ul. Jana Pawła II 38c, 59-700 Bolesławiec',
#    'Numer': '7',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '1000'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '1361'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '1361'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '316'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '684'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '684'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '3'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
# ...
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '0'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '0'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '0'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '0'},
#      {'name': 'MAZUR Aneta', 'votes': '0'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '0'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '0'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '0'},
#      {'name': 'ZYCH Anna', 'votes': '0'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '0'}],
#     'total votes': '0'}]},
#  '485229': {'id': '485229',
#   'info': {'Siedziba': 'Wojewódzki Szpital dla Nerwowo i Psychicznie Chorych w Bolesławcu, Aleja Tysiąclecia 30, 59-700 Bolesławiec',
#    'Numer': '23',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '450'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '293'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '293'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '426'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '24'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '24'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '0'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
#     'count': '0'},
#    {'id': '8d.',
#     'name': 'Liczba kopert zwrotnych, w których znajdowała się niezaklejona koperta na kartę do głosowania',
#     'count': '0'},
#    {'id': '8e.',
#     'name': 'Liczba kopert na kartę do głosowania wrzuconych do urny',
#     'count': '0'},
#    {'id': '9.', 'name': 'Liczba kart wyjętych z urny', 'count': '24'},
#    {'id': '9a.',
#     'name': 'w tym liczba kart wyjętych z kopert na karty do głosowania',
#     'count': '0'},
#    {'id': '10.',
#     'name': 'Liczba kart nieważnych (innych niż urzędowo ustalone lub nieopatrzonych pieczęcią obwodowej komisji wyborczej)',
#     'count': '0'},
#    {'id': '11.', 'name': 'Liczba kart ważnych', 'count': '24'},
#    {'id': '12.',
#     'name': 'Liczba głosów nieważnych (z kart ważnych)',
#     'count': '2'},
#    {'id': '12a.',
#     'name': 'w tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list',
#     'count': '2'},
#    {'id': '12b.',
#     'name': 'w tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata',
#     'count': '0'},
#    {'id': '12c.',
#     'name': 'w tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście, której rejestracja została unieważniona',
#     'count': '0'},
#    {'id': '13.',
#     'name': 'Liczba głosów ważnych oddanych łącznie na wszystkie listy kandydatów (z kart ważnych)',
#     'count': '22'}],
#   'lists': [{'name': 'Nr listy 1 - KOMITET WYBORCZY WYBORCÓW KONFEDERACJA KORWIN BRAUN LIROY NARODOWCY',
#     'candidates': [{'name': 'IWASZKIEWICZ Robert Jarosław', 'votes': '0'},
#      {'name': 'ŻUREK Piotr Grzegorz', 'votes': '0'},
#      {'name': 'POPLICHA Dagmara Ewa', 'votes': '0'},
#      {'name': 'SZKARUPSKI Daniel', 'votes': '0'},
#      {'name': 'CZERNIAK Hubert Stanisław', 'votes': '0'},
#      {'name': 'GIELERT Katarzyna Zofia', 'votes': '0'},
#      {'name': 'JARMUŁOWICZ Lidia Maria', 'votes': '0'},
#      {'name': 'BIELECKA Halszka Beata', 'votes': '0'},
#      {'name': 'DASZYŃSKA-HERCUŃ Anna Maria', 'votes': '0'},
#      {'name': 'KORWIN-MIKKE Janusz Ryszard', 'votes': '0'}],
#     'total votes': '0'},
#    {'name': 'Nr listy 2 - KOMITET WYBORCZY WIOSNA ROBERTA BIEDRONIA',
#     'candidates': [{'name': 'ŚMISZEK Krzysztof Jan', 'votes': '1'},
#      {'name': 'LUBINIECKA-RÓŻYŁO Katarzyna Elżbieta', 'votes': '0'},
#      {'name': 'CHOJNOWSKI Szymon Piotr', 'votes': '0'},
#      {'name': 'MIGOCZ Izabela Monika', 'votes': '0'},
#      {'name': 'SYSKA Michał Jan', 'votes': '0'},
#      {'name': 'LEMPART Marta Mirosława', 'votes': '0'},
#      {'name': 'PILC Jarosław Stanisław', 'votes': '1'},
#      {'name': 'ODROWSKA Katarzyna', 'votes': '0'},
#      {'name': 'ZATKA Natalia Iwona', 'votes': '0'},
#      {'name': 'KOTARBA Mariusz', 'votes': '0'}],
#     'total votes': '2'},
#    {'name': 'Nr listy 3 - KOALICYJNY KOMITET WYBORCZY KOALICJA EUROPEJSKA PO PSL SLD .N ZIELONI',
#     'candidates': [{'name': 'OCHOJSKA-OKOŃSKA Janina Maria', 'votes': '3'},
#      {'name': 'DUDA Jarosław', 'votes': '1'},
#      {'name': 'SEKUŁA-SZMAJDZIŃSKA Małgorzata Helena', 'votes': '0'},
#      {'name': 'BUŁA Andrzej', 'votes': '0'},
#      {'name': 'ROKICKA Julia Agata', 'votes': '0'},
#      {'name': 'MRZYGŁOCKA Izabela Katarzyna', 'votes': '0'},
#      {'name': 'KOZAKIEWICZ Władysław', 'votes': '0'},
#      {'name': 'STĘPIEŃ Elżbieta Krystyna', 'votes': '0'},
#      {'name': 'PROROK Genowefa Katarzyna', 'votes': '0'},
#      {'name': 'MIESZKOWSKI Krzysztof', 'votes': '0'}],
#     'total votes': '4'},
#    {'name': 'Nr listy 4 - KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ',
#     'candidates': [{'name': 'ZALEWSKA Anna Elżbieta', 'votes': '6'},
#      {'name': 'KEMPA Beata Agnieszka', 'votes': '3'},
#      {'name': 'KŁOSOWSKI Sławomir', 'votes': '1'},
#      {'name': 'KISIELEWICZ Andrzej Marian', 'votes': '1'},
#      {'name': 'SZWED Aleksander Jakub', 'votes': '1'},
#      {'name': 'ŚLUSARZ Rafał Józef', 'votes': '1'},
#      {'name': 'CZOCHARA Katarzyna Beata', 'votes': '0'},
#      {'name': 'BACZYŃSKI Jacek Marcin', 'votes': '2'},
#      {'name': 'ŻOŁNIERUK Beata Izabela', 'votes': '0'},
#      {'name': 'STACHOWIAK-RÓŻECKA Mirosława Agnieszka', 'votes': '0'}],
#     'total votes': '15'},
#    {'name': 'Nr listy 5 - KOALICYJNY KOMITET WYBORCZY LEWICA RAZEM - PARTIA RAZEM, UNIA PRACY, RSS',
#     'candidates': [{'name': 'ZAWISZA Marcelina Monika', 'votes': '0'},
#      {'name': 'PRZYSTAJKO Jerzy', 'votes': '0'},
#      {'name': 'PIWCEWICZ Jolanta Anna', 'votes': '0'},
#      {'name': 'BROWARNY Wojciech Jan', 'votes': '0'},
#      {'name': 'JAROŃSKA Kamila Maria', 'votes': '0'},
#      {'name': 'MAKÓWKA Jacek Edward', 'votes': '0'},
#      {'name': 'STABROWSKA Anna Ewa', 'votes': '0'},
#      {'name': 'DROST Andrzej Oswald', 'votes': '0'},
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '0'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '0'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '1'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '0'},
#      {'name': 'MAZUR Aneta', 'votes': '0'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '0'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '0'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '0'},
#      {'name': 'ZYCH Anna', 'votes': '0'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '0'}],
#     'total votes': '1'}]},
#  '485230': {'id': '485230',
#   'info': {'Siedziba': 'Dom Pomocy Społecznej w Bolesławcu, ul. Piastów 17, 59-700 Bolesławiec',
#    'Numer': '24',
#    'Okręg wyborczy': 'Nr 12 [Wrocław]',
#    'Kod TERYT': '020101',
#    'Województwo': 'dolnośląskie',
#    'Powiat': 'bolesławiecki',
#    'Gmina': 'm. Bolesławiec'},
#   'cards': [{'id': '1.',
#     'name': 'Komisja otrzymała kart do głosowania',
#     'count': '61'},
#    {'id': '2.',
#     'name': 'Liczba wyborców uprawnionych do głosowania (umieszczonych w spisie, z uwzględnieniem dodatkowych formularzy) w chwili zakończenia głosowania',
#     'count': '42'},
#    {'id': '2a.',
#     'name': 'w tym umieszczonych w części A spisu wyborców (obywatele polscy)',
#     'count': '42'},
#    {'id': '2b.',
#     'name': 'w tym umieszczonych w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '3.', 'name': 'Nie wykorzystano kart do głosowania', 'count': '29'},
#    {'id': '4.',
#     'name': 'Liczba wyborców, którym wydano karty do głosowania (liczba podpisów w spisie oraz adnotacje „odmowa podpisu”)',
#     'count': '32'},
#    {'id': '4a.',
#     'name': 'w tym w części A spisu wyborców (obywatele polscy)',
#     'count': '32'},
#    {'id': '4b.',
#     'name': 'w tym w części B spisu wyborców (obywatele UE niebędący obywatelami polskimi)',
#     'count': '0'},
#    {'id': '5.',
#     'name': 'Liczba wyborców głosujących przez pełnomocnika (liczba kart do głosowania wydanych na podstawie otrzymanych przez komisję aktów pełnomocnictwa)',
#     'count': '0'},
#    {'id': '6.',
#     'name': 'Liczba wyborców głosujących na podstawie zaświadczenia o prawie do głosowania',
#     'count': '0'},
#    {'id': '7.',
#     'name': 'Liczba wyborców, którym wysłano pakiety wyborcze',
#     'count': '0'},
#    {'id': '8.', 'name': 'Liczba otrzymanych kopert zwrotnych', 'count': '0'},
#    {'id': '8a.',
#     'name': 'Liczba kopert zwrotnych, w których nie było oświadczenia o osobistym i tajnym oddaniu głosu',
#     'count': '0'},
#    {'id': '8b.',
#     'name': 'Liczba kopert zwrotnych, w których oświadczenie nie było podpisane przez wyborcę',
#     'count': '0'},
#    {'id': '8c.',
#     'name': 'Liczba kopert zwrotnych, w których nie było koperty na kartę do głosowania',
#     'count': '0'},
#    {'id': '8d.',
#     'name': 'Liczba kopert zwrotnych, w których znajdowała się niezaklejona koperta na kartę do głosowania',
#     'count': '0'},
#    {'id': '8e.',
#     'name': 'Liczba kopert na kartę do głosowania wrzuconych do urny',
#     'count': '0'},
#    {'id': '9.', 'name': 'Liczba kart wyjętych z urny', 'count': '32'},
#    {'id': '9a.',
#     'name': 'w tym liczba kart wyjętych z kopert na karty do głosowania',
#     'count': '0'},
#    {'id': '10.',
#     'name': 'Liczba kart nieważnych (innych niż urzędowo ustalone lub nieopatrzonych pieczęcią obwodowej komisji wyborczej)',
#     'count': '0'},
#    {'id': '11.', 'name': 'Liczba kart ważnych', 'count': '32'},
#    {'id': '12.',
#     'name': 'Liczba głosów nieważnych (z kart ważnych)',
#     'count': '6'},
#    {'id': '12a.',
#     'name': 'w tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list',
#     'count': '0'},
#    {'id': '12b.',
#     'name': 'w tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata',
#     'count': '6'},
#    {'id': '12c.',
#     'name': 'w tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście, której rejestracja została unieważniona',
#     'count': '0'},
#    {'id': '13.',
#     'name': 'Liczba głosów ważnych oddanych łącznie na wszystkie listy kandydatów (z kart ważnych)',
#     'count': '26'}],
#   'lists': [{'name': 'Nr listy 1 - KOMITET WYBORCZY WYBORCÓW KONFEDERACJA KORWIN BRAUN LIROY NARODOWCY',
#     'candidates': [{'name': 'IWASZKIEWICZ Robert Jarosław', 'votes': '0'},
#      {'name': 'ŻUREK Piotr Grzegorz', 'votes': '0'},
#      {'name': 'POPLICHA Dagmara Ewa', 'votes': '0'},
#      {'name': 'SZKARUPSKI Daniel', 'votes': '0'},
#      {'name': 'CZERNIAK Hubert Stanisław', 'votes': '0'},
#      {'name': 'GIELERT Katarzyna Zofia', 'votes': '0'},
#      {'name': 'JARMUŁOWICZ Lidia Maria', 'votes': '0'},
#      {'name': 'BIELECKA Halszka Beata', 'votes': '0'},
#      {'name': 'DASZYŃSKA-HERCUŃ Anna Maria', 'votes': '0'},
#      {'name': 'KORWIN-MIKKE Janusz Ryszard', 'votes': '0'}],
#     'total votes': '0'},
#    {'name': 'Nr listy 2 - KOMITET WYBORCZY WIOSNA ROBERTA BIEDRONIA',
#     'candidates': [{'name': 'ŚMISZEK Krzysztof Jan', 'votes': '1'},
#      {'name': 'LUBINIECKA-RÓŻYŁO Katarzyna Elżbieta', 'votes': '0'},
#      {'name': 'CHOJNOWSKI Szymon Piotr', 'votes': '0'},
#      {'name': 'MIGOCZ Izabela Monika', 'votes': '1'},
#      {'name': 'SYSKA Michał Jan', 'votes': '0'},
#      {'name': 'LEMPART Marta Mirosława', 'votes': '2'},
#      {'name': 'PILC Jarosław Stanisław', 'votes': '0'},
#      {'name': 'ODROWSKA Katarzyna', 'votes': '0'},
#      {'name': 'ZATKA Natalia Iwona', 'votes': '0'},
#      {'name': 'KOTARBA Mariusz', 'votes': '0'}],
#     'total votes': '4'},
#    {'name': 'Nr listy 3 - KOALICYJNY KOMITET WYBORCZY KOALICJA EUROPEJSKA PO PSL SLD .N ZIELONI',
#     'candidates': [{'name': 'OCHOJSKA-OKOŃSKA Janina Maria', 'votes': '3'},
#      {'name': 'DUDA Jarosław', 'votes': '0'},
#      {'name': 'SEKUŁA-SZMAJDZIŃSKA Małgorzata Helena', 'votes': '2'},
#      {'name': 'BUŁA Andrzej', 'votes': '1'},
#      {'name': 'ROKICKA Julia Agata', 'votes': '1'},
#      {'name': 'MRZYGŁOCKA Izabela Katarzyna', 'votes': '0'},
#      {'name': 'KOZAKIEWICZ Władysław', 'votes': '0'},
#      {'name': 'STĘPIEŃ Elżbieta Krystyna', 'votes': '0'},
#      {'name': 'PROROK Genowefa Katarzyna', 'votes': '0'},
#      {'name': 'MIESZKOWSKI Krzysztof', 'votes': '0'}],
#     'total votes': '7'},
#    {'name': 'Nr listy 4 - KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ',
#     'candidates': [{'name': 'ZALEWSKA Anna Elżbieta', 'votes': '3'},
#      {'name': 'KEMPA Beata Agnieszka', 'votes': '3'},
#      {'name': 'KŁOSOWSKI Sławomir', 'votes': '2'},
#      {'name': 'KISIELEWICZ Andrzej Marian', 'votes': '2'},
#      {'name': 'SZWED Aleksander Jakub', 'votes': '1'},
#      {'name': 'ŚLUSARZ Rafał Józef', 'votes': '1'},
#      {'name': 'CZOCHARA Katarzyna Beata', 'votes': '0'},
#      {'name': 'BACZYŃSKI Jacek Marcin', 'votes': '0'},
#      {'name': 'ŻOŁNIERUK Beata Izabela', 'votes': '0'},
#      {'name': 'STACHOWIAK-RÓŻECKA Mirosława Agnieszka', 'votes': '0'}],
#     'total votes': '12'},
#    {'name': 'Nr listy 5 - KOALICYJNY KOMITET WYBORCZY LEWICA RAZEM - PARTIA RAZEM, UNIA PRACY, RSS',
#     'candidates': [{'name': 'ZAWISZA Marcelina Monika', 'votes': '0'},
#      {'name': 'PRZYSTAJKO Jerzy', 'votes': '2'},
#      {'name': 'PIWCEWICZ Jolanta Anna', 'votes': '0'},
#      {'name': 'BROWARNY Wojciech Jan', 'votes': '0'},
#      {'name': 'JAROŃSKA Kamila Maria', 'votes': '1'},
#      {'name': 'MAKÓWKA Jacek Edward', 'votes': '0'},
#      {'name': 'STABROWSKA Anna Ewa', 'votes': '0'},
#      {'name': 'DROST Andrzej Oswald', 'votes': '0'},
#      {'name': 'BURAKOWSKA Krystyna Anna', 'votes': '0'},
#      {'name': 'CHUDY Filip', 'votes': '0'}],
#     'total votes': '3'},
#    {'name': "Nr listy 6 - KOMITET WYBORCZY WYBORCÓW KUKIZ'15",
#     'candidates': [{'name': 'ŚCIGAJ Agnieszka', 'votes': '0'},
#      {'name': 'GRABOWSKI Paweł', 'votes': '0'},
#      {'name': 'MAZUR Aneta', 'votes': '0'},
#      {'name': 'KUBALA Marek Zdzisław', 'votes': '0'},
#      {'name': 'LICZNAR Katarzyna Anna', 'votes': '0'},
#      {'name': 'CHARYTONIUK Gracjan', 'votes': '0'},
#      {'name': 'OLSZEWSKA Małgorzata', 'votes': '0'},
#      {'name': 'JAGIEŁŁO Wojciech Jan', 'votes': '0'},
#      {'name': 'ZYCH Anna', 'votes': '0'},
#      {'name': 'KRÓLAK Marcin Stanisław', 'votes': '0'}],
#     'total votes': '0'}]}}
